# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanbanerjee32/stable-diffusion-textual-inversion-demo/blob/main/SD_text_inv_gradio_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install -q --upgrade transformers==4.25.1 diffusers accelerate open_clip_torch gradio
# ftfy

# %%
from huggingface_hub import HfApi
from google.colab import userdata
userdata.get('HF_TOKEN')
api = HfApi()

# %%
# assignment repo
# !git clone https://github.com/sayanbanerjee32/stable-diffusion-textual-inversion-demo
# Out:
# Cloning into 'stable-diffusion-textual-inversion-demo'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 54 (delta 24), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (54/54), 825.23 KiB | 6.65 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
## move python files to outside
# !mv stable-diffusion-textual-inversion-demo/*.py .

# %%
import app
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# learned_embeds.bin:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# learned_embeds.bin:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# learned_embeds.bin:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# learned_embeds.bin:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# learned_embeds.bin:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ...

# %%
import os
os.makedirs('to_upload', exist_ok=True)

# %%
# !cp *.py to_upload
# !cp stable-diffusion-textual-inversion-demo/requirements.txt to_upload

# %%
api.upload_folder(
    folder_path="./to_upload",
    repo_id="sayanbanerjee32/stable-diffusion-textual-inversion-demo",
    repo_type="space",
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/spaces/sayanbanerjee32/stable-diffusion-textual-inversion-demo/commit/b8da7b9dff7a56a4fdd04f1dda0d7eb940ef7679', commit_message='Upload folder using huggingface_hub', commit_description='', oid='b8da7b9dff7a56a4fdd04f1dda0d7eb940ef7679', pr_url=None, pr_revision=None, pr_num=None)
